# %%
import pandas as pd

# %%
df = pd.read_csv("../../results/tables/sn_sp/classifications.illumina.csv")
df.set_index(["run", "drug", "tool"], inplace=True, drop=False, verify_integrity=True)
df
# Out:
#                                         run       drug classification  \
# run        drug      tool
# ERR4796918 amikacin  drprg       ERR4796918   amikacin             TN
# ERR4796751 amikacin  drprg       ERR4796751   amikacin             TN
# ERR4797124 amikacin  drprg       ERR4797124   amikacin             TN
# ERR4811595 amikacin  drprg       ERR4811595   amikacin             TN
# ERR3287778 amikacin  drprg       ERR3287778   amikacin             TN
# ...                                     ...        ...            ...
# ERR2510525 delamanid tbprofiler  ERR2510525  delamanid             TN
# ERR4811882 delamanid tbprofiler  ERR4811882  delamanid             TN
# ERR8699736 delamanid tbprofiler  ERR8699736  delamanid             TN
# ERR4828640 delamanid tbprofiler  ERR4828640  delamanid             TN
# ERR4830324 delamanid tbprofiler  ERR4830324  delamanid             TN
#
#                                        tool
# run        drug      tool
# ERR4796918 amikacin  drprg            drprg
# ERR4796751 amikacin  drprg            drprg
# ERR4797124 amikacin  drprg            drprg
# ERR4811595 amikacin  drprg            drprg
# ERR3287778 amikacin  drprg            drprg
# ...                                     ...
# ERR2510525 delamanid tbprofiler  tbprofiler
# ERR4811882 delamanid tbprofiler  tbprofiler
# ERR8699736 delamanid tbprofiler  tbprofiler
# ERR4828640 delamanid tbprofiler  tbprofiler
# ERR4830324 delamanid tbprofiler  tbprofiler
#
# [7326 rows x 4 columns]

# %%
for _, row in df.query("tool=='drprg' and classification=='FN'").iterrows():
    run = row["run"]
    drug = row["drug"]
    
    if drug != "ethionamide":
        continue
    
    mykrobe_clf = df.at[(run, drug, "mykrobe"), "classification"]
    tbp_clf = df.at[(run, drug, "tbprofiler"), "classification"]
    drprg_clf = df.at[(run, drug, "drprg"), "classification"]
    
    
    if not mykrobe_clf.startswith("F"):
        print(run, drug, "mykrobe")
    elif not tbp_clf.startswith("F"):
        print(run, drug, "tbprofiler")
    else:
        print(run, drug, "FN on all")
# Out:
# ERR4797124 ethionamide FN on all
# ERR1034939 ethionamide FN on all
# ERR4797992 ethionamide FN on all
# ERR4813461 ethionamide FN on all
# ERR4797434 ethionamide FN on all
# ERR8975693 ethionamide mykrobe
# ERR4813312 ethionamide FN on all
# ERR4829736 ethionamide FN on all
# ERR4796435 ethionamide tbprofiler
# ERR4799420 ethionamide FN on all
# ERR4800308 ethionamide mykrobe
# ERR4797669 ethionamide FN on all
# ERR4800322 ethionamide FN on all
# ERR2516709 ethionamide mykrobe

# %% [markdown]
# RIF
# ---
# SRR14196840 FN mykrobe calls rpoB_L452P-CTG761160CCG (5/85) drprg didn't discover the variant (rpoB 1454). There is a variant at 1449 that has a null genotype and only has depth on the reverse ref allele, so maybe this meant de novo didn't get triggered...
# ERR9030523 FN mykrobe calls rpoB_D435V-GAC761109GTC (1/29) drprg didn't discover the variant (rpoB 1403)
#
# STM
# ---
# SRR12395106 FN mykrobe calls some HET looking long indels (~pos. 329 in gid) drprg calls a novel variant gid_V110V, a8V and D67Y (all called by tbprofiler)
# SRR12395154 FN mykrobe calls rpsL_K43R-AAG781686AGG (8/13) drprg called the allele, but failed FRS (0.52)
#
# ETO
# ---
#
#
#
# PZA
# ---
# SRR12395331 FN mykrobe calls pncA_R154G-CCT2288780CCC (0/13) drprg calls the correct allele, but fails FRS (0.54)

# %%
df.query()
