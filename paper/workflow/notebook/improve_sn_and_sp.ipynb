# %%
import pandas as pd

# %%
df = pd.read_csv("../../results/tables/sn_sp/classifications.illumina.csv")
df.set_index(["run", "drug", "tool"], inplace=True, drop=False, verify_integrity=True)
df
# Out:
#                                            run          drug classification  \
# run        drug         tool
# ERR4829858 moxifloxacin drprg       ERR4829858  moxifloxacin             TN
# ERR4831908 moxifloxacin drprg       ERR4831908  moxifloxacin             TN
# ERR4811046 moxifloxacin drprg       ERR4811046  moxifloxacin             TN
# ERR4796277 moxifloxacin drprg       ERR4796277  moxifloxacin             TN
# ERR2510304 moxifloxacin drprg       ERR2510304  moxifloxacin             FP
# ...                                        ...           ...            ...
# ERR4832049 isoniazid    tbprofiler  ERR4832049     isoniazid             TP
# ERR8975400 isoniazid    tbprofiler  ERR8975400     isoniazid             TN
# ERR4828459 isoniazid    tbprofiler  ERR4828459     isoniazid             TN
# ERR4822568 isoniazid    tbprofiler  ERR4822568     isoniazid             TN
# ERR4797440 isoniazid    tbprofiler  ERR4797440     isoniazid             FN
#
#                                           tool
# run        drug         tool
# ERR4829858 moxifloxacin drprg            drprg
# ERR4831908 moxifloxacin drprg            drprg
# ERR4811046 moxifloxacin drprg            drprg
# ERR4796277 moxifloxacin drprg            drprg
# ERR2510304 moxifloxacin drprg            drprg
# ...                                        ...
# ERR4832049 isoniazid    tbprofiler  tbprofiler
# ERR8975400 isoniazid    tbprofiler  tbprofiler
# ERR4828459 isoniazid    tbprofiler  tbprofiler
# ERR4822568 isoniazid    tbprofiler  tbprofiler
# ERR4797440 isoniazid    tbprofiler  tbprofiler
#
# [235281 rows x 4 columns]

# %%
df.query("tool == 'drprg' and drug == 'ethionamide'")
# Out:
#                                      run         drug classification   tool
# run        drug        tool
# ERR4828232 ethionamide drprg  ERR4828232  ethionamide             TN  drprg
# ERR4811890 ethionamide drprg  ERR4811890  ethionamide             TN  drprg
# ERR4831014 ethionamide drprg  ERR4831014  ethionamide             TP  drprg
# ERR4812127 ethionamide drprg  ERR4812127  ethionamide             TN  drprg
# ERR4798348 ethionamide drprg  ERR4798348  ethionamide             TN  drprg
# ...                                  ...          ...            ...    ...
# ERR4813284 ethionamide drprg  ERR4813284  ethionamide             TP  drprg
# ERR2510303 ethionamide drprg  ERR2510303  ethionamide             TP  drprg
# ERR4831167 ethionamide drprg  ERR4831167  ethionamide             FP  drprg
# ERR3287767 ethionamide drprg  ERR3287767  ethionamide             TN  drprg
# ERR2510612 ethionamide drprg  ERR2510612  ethionamide             TN  drprg
#
# [7222 rows x 4 columns]

# %%
rf = 16
af = 10
rr = 16
ar = 24
r = rf+rr
a = af+ar
print(f"FRS {a/(r+a)}")
print(f"SB {min(af, ar)/(af+ar)}")
# Out:
# FRS 0.5151515151515151
# SB 0.29411764705882354

# %%
for _, row in df.query("tool=='drprg' and classification=='FN' and drug=='rifampicin'").iterrows():
    run = row["run"]
    drug = row["drug"]
    
    mykrobe_clf = df.at[(run, drug, "mykrobe"), "classification"]
    tbp_clf = df.at[(run, drug, "tbprofiler"), "classification"]
    drprg_clf = df.at[(run, drug, "drprg"), "classification"]
    
    if not mykrobe_clf.startswith("F"):
        print(run, drug, "mykrobe")
    elif not tbp_clf.startswith("F"):
        print(run, drug, "tbprofiler")
#     else:
#         print(run, drug, "FN on all")
# Out:
# SRR6797871 rifampicin mykrobe
# ERR8975535 rifampicin tbprofiler
# ERR2510714 rifampicin mykrobe
# ERR4829975 rifampicin mykrobe
# ERR4813384 rifampicin tbprofiler
# ERR4829916 rifampicin mykrobe
# SRR6824417 rifampicin tbprofiler
# ERR4796347 rifampicin mykrobe
# ERR4796867 rifampicin tbprofiler
# SRR6824707 rifampicin mykrobe
# SRR6824431 rifampicin mykrobe
# ERR4797700 rifampicin tbprofiler
# SRR6824642 rifampicin mykrobe
# ERR4796357 rifampicin tbprofiler
# ERR4809240 rifampicin mykrobe
# ERR4831827 rifampicin mykrobe
# SRR6824339 rifampicin tbprofiler
# ERR4822586 rifampicin mykrobe
# SRR6824700 rifampicin tbprofiler
# SRR6824702 rifampicin tbprofiler
# ERR4830156 rifampicin tbprofiler
# ERR4797174 rifampicin mykrobe
# SRR6797288 rifampicin mykrobe
# SRR6824581 rifampicin tbprofiler
# ERR4797284 rifampicin tbprofiler
# SRR6824414 rifampicin mykrobe
# SRR6824698 rifampicin tbprofiler
# ERR4828462 rifampicin mykrobe
# ERR4812971 rifampicin mykrobe
# ERR4809254 rifampicin tbprofiler
# ERR4813371 rifampicin mykrobe
# ERR4831634 rifampicin tbprofiler
# SRR6824299 rifampicin mykrobe
# ERR4812981 rifampicin mykrobe
# ERR4796787 rifampicin mykrobe
# ERR2510340 rifampicin tbprofiler

# %%
pheno
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 pheno
#
# NameError: name 'pheno' is not defined

# %%
inh_fp.intersection(eto_fp)
# Out:
# {'SRR12395058', 'SRR12395148', 'SRR12395329'}

# %% [markdown]
# RIF
# ---
# SRR14196840 FN mykrobe calls rpoB_L452P-CTG761160CCG (5/85) drprg didn't discover the variant (rpoB 1454). There is a variant at 1449 that has a null genotype and only has depth on the reverse ref allele, so maybe this meant de novo didn't get triggered...
# ERR9030523 FN mykrobe calls rpoB_D435V-GAC761109GTC (1/29) drprg didn't discover the variant (rpoB 1403)
#
# STM
# ---
# SRR12395106 FN mykrobe calls some HET looking long indels (~pos. 329 in gid) drprg calls a novel variant gid_V110V, a8V and D67Y (all called by tbprofiler)
# SRR12395154 FN mykrobe calls rpsL_K43R-AAG781686AGG (8/13) drprg called the allele, but failed FRS (0.52)
#
# ETO
# ---
#
#
#
# PZA
# ---
# SRR12395331 FN mykrobe calls pncA_R154G-CCT2288780CCC (0/13) drprg calls the correct allele, but fails FRS (0.54)

# %%
df.query()
