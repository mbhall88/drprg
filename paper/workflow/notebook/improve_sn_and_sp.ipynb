# %%
import pandas as pd

# %%
df = pd.read_csv("../../results/tables/sn_sp/classifications.nanopore.csv")
df.set_index(["run", "drug", "tool"], inplace=True, drop=False, verify_integrity=True)
df
# Out:
#                                            run        drug classification  \
# run         drug       tool
# SRR14196818 ethambutol drprg       SRR14196818  ethambutol             FP
# SRR12395465 ethambutol drprg       SRR12395465  ethambutol             TN
# SRR12395334 ethambutol drprg       SRR12395334  ethambutol             TN
# ERR9030371  ethambutol drprg        ERR9030371  ethambutol             TP
# SRR12395201 ethambutol drprg       SRR12395201  ethambutol             TN
# ...                                        ...         ...            ...
# SRR12395264 rifampicin tbprofiler  SRR12395264  rifampicin             TN
# SRR12395426 rifampicin tbprofiler  SRR12395426  rifampicin             TN
# SRR12395066 rifampicin tbprofiler  SRR12395066  rifampicin             TN
# ERR9030501  rifampicin tbprofiler   ERR9030501  rifampicin             TN
# SRR12395458 rifampicin tbprofiler  SRR12395458  rifampicin             TN
#
#                                          tool
# run         drug       tool
# SRR14196818 ethambutol drprg            drprg
# SRR12395465 ethambutol drprg            drprg
# SRR12395334 ethambutol drprg            drprg
# ERR9030371  ethambutol drprg            drprg
# SRR12395201 ethambutol drprg            drprg
# ...                                       ...
# SRR12395264 rifampicin tbprofiler  tbprofiler
# SRR12395426 rifampicin tbprofiler  tbprofiler
# SRR12395066 rifampicin tbprofiler  tbprofiler
# ERR9030501  rifampicin tbprofiler  tbprofiler
# SRR12395458 rifampicin tbprofiler  tbprofiler
#
# [6615 rows x 4 columns]

# %%
df.query("tool == 'drprg' and classification=='FP' and drug == 'ethionamide'")
# Out:
#                                        run         drug classification   tool
# run         drug        tool
# SRR12395148 ethionamide drprg  SRR12395148  ethionamide             FP  drprg
# SRR12395083 ethionamide drprg  SRR12395083  ethionamide             FP  drprg
# SRR12395219 ethionamide drprg  SRR12395219  ethionamide             FP  drprg
# SRR12395154 ethionamide drprg  SRR12395154  ethionamide             FP  drprg
# SRR12395161 ethionamide drprg  SRR12395161  ethionamide             FP  drprg
# SRR12395225 ethionamide drprg  SRR12395225  ethionamide             FP  drprg
# SRR12395176 ethionamide drprg  SRR12395176  ethionamide             FP  drprg
# SRR12395329 ethionamide drprg  SRR12395329  ethionamide             FP  drprg
# SRR12395242 ethionamide drprg  SRR12395242  ethionamide             FP  drprg
# SRR12395288 ethionamide drprg  SRR12395288  ethionamide             FP  drprg
# SRR12395107 ethionamide drprg  SRR12395107  ethionamide             FP  drprg
# SRR12395145 ethionamide drprg  SRR12395145  ethionamide             FP  drprg
# SRR12395205 ethionamide drprg  SRR12395205  ethionamide             FP  drprg
# SRR12395361 ethionamide drprg  SRR12395361  ethionamide             FP  drprg
# SRR12395376 ethionamide drprg  SRR12395376  ethionamide             FP  drprg
# SRR12395150 ethionamide drprg  SRR12395150  ethionamide             FP  drprg
# SRR12395043 ethionamide drprg  SRR12395043  ethionamide             FP  drprg
# SRR12395130 ethionamide drprg  SRR12395130  ethionamide             FP  drprg
# SRR12395456 ethionamide drprg  SRR12395456  ethionamide             FP  drprg
# SRR12395287 ethionamide drprg  SRR12395287  ethionamide             FP  drprg
# SRR12395297 ethionamide drprg  SRR12395297  ethionamide             FP  drprg
# SRR12395190 ethionamide drprg  SRR12395190  ethionamide             FP  drprg
# SRR12395454 ethionamide drprg  SRR12395454  ethionamide             FP  drprg
# SRR12395212 ethionamide drprg  SRR12395212  ethionamide             FP  drprg
# ERR9030378  ethionamide drprg   ERR9030378  ethionamide             FP  drprg
# SRR12395345 ethionamide drprg  SRR12395345  ethionamide             FP  drprg
# SRR12395432 ethionamide drprg  SRR12395432  ethionamide             FP  drprg
# SRR12395058 ethionamide drprg  SRR12395058  ethionamide             FP  drprg
# SRR12395282 ethionamide drprg  SRR12395282  ethionamide             FP  drprg
# SRR12395458 ethionamide drprg  SRR12395458  ethionamide             FP  drprg

# %%
rf = 16
af = 10
rr = 16
ar = 24
r = rf+rr
a = af+ar
print(f"FRS {a/(r+a)}")
print(f"SB {min(af, ar)/(af+ar)}")
# Out:
# FRS 0.5151515151515151
# SB 0.29411764705882354

# %%
stm_fp = set()
inh_fp = set()
eto_fp = set()

# %%
for _, row in df.query("tool=='drprg' and classification=='FP'").iterrows():
    run = row["run"]
    drug = row["drug"]
    
    if drug != "isoniazid":
        continue
    
    mykrobe_clf = df.at[(run, drug, "mykrobe"), "classification"]
    tbp_clf = df.at[(run, drug, "tbprofiler"), "classification"]
    drprg_clf = df.at[(run, drug, "drprg"), "classification"]
    
    inh_fp.add(run)
    if not mykrobe_clf.startswith("F"):
        print(run, drug, "mykrobe")
    elif not tbp_clf.startswith("F"):
        print(run, drug, "tbprofiler")
    else:
        print(run, drug, "FN on all")
# Out:
# SRR12395334 isoniazid mykrobe
# SRR12395201 isoniazid mykrobe
# SRR12395183 isoniazid tbprofiler
# SRR12395197 isoniazid mykrobe
# SRR12395406 isoniazid mykrobe
# SRR12395119 isoniazid mykrobe
# SRR12395365 isoniazid mykrobe
# SRR12395155 isoniazid tbprofiler
# SRR12395148 isoniazid tbprofiler
# SRR12395200 isoniazid mykrobe
# SRR12395143 isoniazid tbprofiler
# SRR12395271 isoniazid mykrobe
# SRR12395116 isoniazid mykrobe
# SRR12395091 isoniazid mykrobe
# SRR12395211 isoniazid mykrobe
# SRR12395168 isoniazid mykrobe
# SRR12395323 isoniazid mykrobe
# SRR12395147 isoniazid tbprofiler
# SRR12395326 isoniazid tbprofiler
# SRR12395378 isoniazid tbprofiler
# SRR12395363 isoniazid mykrobe
# SRR12395118 isoniazid mykrobe
# SRR12395385 isoniazid mykrobe
# SRR12395435 isoniazid mykrobe
# SRR12395430 isoniazid tbprofiler
# SRR12395231 isoniazid mykrobe
# SRR12395329 isoniazid mykrobe
# SRR12395369 isoniazid mykrobe
# ERR9030449 isoniazid FN on all
# SRR12395060 isoniazid mykrobe
# SRR12395246 isoniazid mykrobe
# SRR12395299 isoniazid tbprofiler
# SRR12395295 isoniazid mykrobe
# SRR12395275 isoniazid tbprofiler
# SRR12395156 isoniazid tbprofiler
# ERR9030327 isoniazid FN on all
# SRR12395056 isoniazid tbprofiler
# SRR12395216 isoniazid mykrobe
# SRR12395124 isoniazid mykrobe
# SRR12395121 isoniazid tbprofiler
# SRR12395207 isoniazid mykrobe
# SRR12395352 isoniazid mykrobe
# SRR12395293 isoniazid mykrobe
# SRR12395146 isoniazid tbprofiler
# SRR12395400 isoniazid tbprofiler
# SRR12395144 isoniazid tbprofiler
# SRR12395247 isoniazid mykrobe
# SRR12395109 isoniazid mykrobe
# SRR12395153 isoniazid tbprofiler
# SRR12395440 isoniazid FN on all
# SRR12395117 isoniazid mykrobe
# ERR9030321 isoniazid FN on all
# SRR12395240 isoniazid mykrobe
# SRR12395237 isoniazid mykrobe
# SRR12395057 isoniazid mykrobe
# SRR12395296 isoniazid mykrobe
# SRR12395198 isoniazid tbprofiler
# SRR12395362 isoniazid mykrobe
# SRR12395151 isoniazid tbprofiler
# SRR12395443 isoniazid mykrobe
# SRR12395070 isoniazid mykrobe
# ERR9030252 isoniazid tbprofiler
# SRR12395221 isoniazid mykrobe
# SRR12395304 isoniazid mykrobe
# SRR12395058 isoniazid tbprofiler
# SRR12395466 isoniazid mykrobe

# %%
inh_fp.intersection(eto_fp)
# Out:
# {'SRR12395058', 'SRR12395148', 'SRR12395329'}

# %% [markdown]
# RIF
# ---
# SRR14196840 FN mykrobe calls rpoB_L452P-CTG761160CCG (5/85) drprg didn't discover the variant (rpoB 1454). There is a variant at 1449 that has a null genotype and only has depth on the reverse ref allele, so maybe this meant de novo didn't get triggered...
# ERR9030523 FN mykrobe calls rpoB_D435V-GAC761109GTC (1/29) drprg didn't discover the variant (rpoB 1403)
#
# STM
# ---
# SRR12395106 FN mykrobe calls some HET looking long indels (~pos. 329 in gid) drprg calls a novel variant gid_V110V, a8V and D67Y (all called by tbprofiler)
# SRR12395154 FN mykrobe calls rpsL_K43R-AAG781686AGG (8/13) drprg called the allele, but failed FRS (0.52)
#
# ETO
# ---
#
#
#
# PZA
# ---
# SRR12395331 FN mykrobe calls pncA_R154G-CCT2288780CCC (0/13) drprg calls the correct allele, but fails FRS (0.54)

# %%
df.query()
