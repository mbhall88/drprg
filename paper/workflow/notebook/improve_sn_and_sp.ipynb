# %%
import pandas as pd

# %%
df = pd.read_csv("../../results/tables/sn_sp/gene_deletion/classifications.illumina.csv")
df.set_index(["run", "drug", "tool"], inplace=True, drop=False, verify_integrity=True)
df
# Out:
#                                            run          drug classification  \
# run        drug         tool
# ERR4829858 moxifloxacin drprg       ERR4829858  moxifloxacin             TN
# ERR4831908 moxifloxacin drprg       ERR4831908  moxifloxacin             TN
# ERR4811046 moxifloxacin drprg       ERR4811046  moxifloxacin             TN
# ERR4796277 moxifloxacin drprg       ERR4796277  moxifloxacin             TN
# ERR2510304 moxifloxacin drprg       ERR2510304  moxifloxacin             FP
# ...                                        ...           ...            ...
# ERR4832049 isoniazid    tbprofiler  ERR4832049     isoniazid             TP
# ERR8975400 isoniazid    tbprofiler  ERR8975400     isoniazid             TN
# ERR4828459 isoniazid    tbprofiler  ERR4828459     isoniazid             TN
# ERR4822568 isoniazid    tbprofiler  ERR4822568     isoniazid             TN
# ERR4797440 isoniazid    tbprofiler  ERR4797440     isoniazid             FN
#
#                                           tool
# run        drug         tool
# ERR4829858 moxifloxacin drprg            drprg
# ERR4831908 moxifloxacin drprg            drprg
# ERR4811046 moxifloxacin drprg            drprg
# ERR4796277 moxifloxacin drprg            drprg
# ERR2510304 moxifloxacin drprg            drprg
# ...                                        ...
# ERR4832049 isoniazid    tbprofiler  tbprofiler
# ERR8975400 isoniazid    tbprofiler  tbprofiler
# ERR4828459 isoniazid    tbprofiler  tbprofiler
# ERR4822568 isoniazid    tbprofiler  tbprofiler
# ERR4797440 isoniazid    tbprofiler  tbprofiler
#
# [235281 rows x 4 columns]

# %%
df.query("tool=='drprg' and drug=='rifampicin' and classification=='TP'")
# Out:
#                                     run        drug classification   tool
# run        drug       tool
# ERR4812973 rifampicin drprg  ERR4812973  rifampicin             TP  drprg
# ERR4829878 rifampicin drprg  ERR4829878  rifampicin             TP  drprg
# ERR4809300 rifampicin drprg  ERR4809300  rifampicin             TP  drprg
# ERR4831009 rifampicin drprg  ERR4831009  rifampicin             TP  drprg
# ERR4796355 rifampicin drprg  ERR4796355  rifampicin             TP  drprg
# ...                                 ...         ...            ...    ...
# ERR3287834 rifampicin drprg  ERR3287834  rifampicin             TP  drprg
# ERR4829143 rifampicin drprg  ERR4829143  rifampicin             TP  drprg
# ERR4822592 rifampicin drprg  ERR4822592  rifampicin             TP  drprg
# ERR4797738 rifampicin drprg  ERR4797738  rifampicin             TP  drprg
# ERR4813308 rifampicin drprg  ERR4813308  rifampicin             TP  drprg
#
# [3045 rows x 4 columns]

# %%
for _, row in df.query("tool=='drprg' and classification=='FN' and drug=='ethionamide'").iterrows():
    run = row["run"]
    drug = row["drug"]
    
# ERR4822595 ethionamide mykrobe
# ERR4828247 ethionamide mykrobe
# ERR4808990 ethionamide mykrobe
# ERR4796435 ethionamide tbprofiler
# ERR4828339 ethionamide mykrobe
# ERR4822376 ethionamide mykrobe
# ERR3287718 ethionamide mykrobe
# ERR4796609 ethionamide mykrobe
# ERR4809350 ethionamide mykrobe
# ERR4797763 ethionamide mykrobe
# ERR4808962 ethionamide mykrobe
# ERR3287785 ethionamide mykrobe
# ERR8975693 ethionamide mykrobe
# ERR3287382 ethionamide mykrobe
# ERR4797440 ethionamide mykrobe

# %%
df.query("run=='ERR4831905'")
# Out:
#                                            run          drug classification  \
# run        drug         tool
# ERR4831905 kanamycin    drprg       ERR4831905     kanamycin             TN
#                         mykrobe     ERR4831905     kanamycin             TN
#                         tbprofiler  ERR4831905     kanamycin             TN
#            ethionamide  drprg       ERR4831905   ethionamide             FN
#                         mykrobe     ERR4831905   ethionamide             TP
#                         tbprofiler  ERR4831905   ethionamide             TP
#            levofloxacin drprg       ERR4831905  levofloxacin             TN
#                         mykrobe     ERR4831905  levofloxacin             TN
#                         tbprofiler  ERR4831905  levofloxacin             TN
#            delamanid    drprg       ERR4831905     delamanid             TN
#                         mykrobe     ERR4831905     delamanid             TN
#                         tbprofiler  ERR4831905     delamanid             TN
#
#                                           tool
# run        drug         tool
# ERR4831905 kanamycin    drprg            drprg
#                         mykrobe        mykrobe
#                         tbprofiler  tbprofiler
#            ethionamide  drprg            drprg
#                         mykrobe        mykrobe
#                         tbprofiler  tbprofiler
#            levofloxacin drprg            drprg
#                         mykrobe        mykrobe
#                         tbprofiler  tbprofiler
#            delamanid    drprg            drprg
#                         mykrobe        mykrobe
#                         tbprofiler  tbprofiler

# %%
inh_fp.intersection(eto_fp)
# Out:
# {'SRR12395058', 'SRR12395148', 'SRR12395329'}

# %% [markdown]
# RIF
# ---
# SRR14196840 FN mykrobe calls rpoB_L452P-CTG761160CCG (5/85) drprg didn't discover the variant (rpoB 1454). There is a variant at 1449 that has a null genotype and only has depth on the reverse ref allele, so maybe this meant de novo didn't get triggered...
# ERR9030523 FN mykrobe calls rpoB_D435V-GAC761109GTC (1/29) drprg didn't discover the variant (rpoB 1403)
#
# STM
# ---
# SRR12395106 FN mykrobe calls some HET looking long indels (~pos. 329 in gid) drprg calls a novel variant gid_V110V, a8V and D67Y (all called by tbprofiler)
# SRR12395154 FN mykrobe calls rpsL_K43R-AAG781686AGG (8/13) drprg called the allele, but failed FRS (0.52)
#
# ETO
# ---
#
#
#
# PZA
# ---
# SRR12395331 FN mykrobe calls pncA_R154G-CCT2288780CCC (0/13) drprg calls the correct allele, but fails FRS (0.54)

# %%
df.query()
