# %%
import pandas as pd

# %%
df = pd.read_csv("../../results/tables/sn_sp/classifications.illumina.csv")
df.set_index(["run", "drug", "tool"], inplace=True, drop=False, verify_integrity=True)
df
# Out:
#                                            run          drug classification  \
# run        drug         tool
# ERR4828232 kanamycin    drprg       ERR4828232     kanamycin             TN
# ERR4811890 kanamycin    drprg       ERR4811890     kanamycin             TN
# ERR4831014 kanamycin    drprg       ERR4831014     kanamycin             FP
# ERR4812127 kanamycin    drprg       ERR4812127     kanamycin             TN
# ERR4798348 kanamycin    drprg       ERR4798348     kanamycin             TN
# ...                                        ...           ...            ...
# ERR4811089 streptomycin tbprofiler  ERR4811089  streptomycin             TN
# ERR2510711 streptomycin tbprofiler  ERR2510711  streptomycin             TP
# ERR4811919 streptomycin tbprofiler  ERR4811919  streptomycin             FN
# ERR3287767 streptomycin tbprofiler  ERR3287767  streptomycin             TN
# ERR2510612 streptomycin tbprofiler  ERR2510612  streptomycin             TN
#
#                                           tool
# run        drug         tool
# ERR4828232 kanamycin    drprg            drprg
# ERR4811890 kanamycin    drprg            drprg
# ERR4831014 kanamycin    drprg            drprg
# ERR4812127 kanamycin    drprg            drprg
# ERR4798348 kanamycin    drprg            drprg
# ...                                        ...
# ERR4811089 streptomycin tbprofiler  tbprofiler
# ERR2510711 streptomycin tbprofiler  tbprofiler
# ERR4811919 streptomycin tbprofiler  tbprofiler
# ERR3287767 streptomycin tbprofiler  tbprofiler
# ERR2510612 streptomycin tbprofiler  tbprofiler
#
# [235281 rows x 4 columns]

# %%
df.query("tool == 'drprg' and drug == 'ethionamide'")
# Out:
#                                      run         drug classification   tool
# run        drug        tool
# ERR4828232 ethionamide drprg  ERR4828232  ethionamide             TN  drprg
# ERR4811890 ethionamide drprg  ERR4811890  ethionamide             TN  drprg
# ERR4831014 ethionamide drprg  ERR4831014  ethionamide             TP  drprg
# ERR4812127 ethionamide drprg  ERR4812127  ethionamide             TN  drprg
# ERR4798348 ethionamide drprg  ERR4798348  ethionamide             TN  drprg
# ...                                  ...          ...            ...    ...
# ERR4813284 ethionamide drprg  ERR4813284  ethionamide             TP  drprg
# ERR2510303 ethionamide drprg  ERR2510303  ethionamide             TP  drprg
# ERR4831167 ethionamide drprg  ERR4831167  ethionamide             FP  drprg
# ERR3287767 ethionamide drprg  ERR3287767  ethionamide             TN  drprg
# ERR2510612 ethionamide drprg  ERR2510612  ethionamide             TN  drprg
#
# [7222 rows x 4 columns]

# %%
rf = 16
af = 10
rr = 16
ar = 24
r = rf+rr
a = af+ar
print(f"FRS {a/(r+a)}")
print(f"SB {min(af, ar)/(af+ar)}")
# Out:
# FRS 0.5151515151515151
# SB 0.29411764705882354

# %%
for _, row in df.query("tool=='drprg' and classification=='FP' and drug=='ethionamide'").iterrows():
    run = row["run"]
    drug = row["drug"]
    
    mykrobe_clf = df.at[(run, drug, "mykrobe"), "classification"]
    tbp_clf = df.at[(run, drug, "tbprofiler"), "classification"]
    drprg_clf = df.at[(run, drug, "drprg"), "classification"]
    
    if not mykrobe_clf.startswith("F"):
        print(run, drug, "mykrobe")
    elif not tbp_clf.startswith("F"):
        print(run, drug, "tbprofiler")
#     else:
#         print(run, drug, "FN on all")
# Out:
# ERR4812968 ethionamide mykrobe
# ERR2510506 ethionamide tbprofiler
# ERR4810542 ethionamide mykrobe
# ERR4831744 ethionamide mykrobe
# ERR4831241 ethionamide tbprofiler
# ERR4822290 ethionamide mykrobe
# ERR4811110 ethionamide mykrobe
# ERR4812031 ethionamide mykrobe
# ERR4830782 ethionamide tbprofiler
# ERR4828367 ethionamide mykrobe
# ERR4830820 ethionamide tbprofiler
# ERR2510395 ethionamide mykrobe
# ERR4797114 ethionamide mykrobe
# ERR4830831 ethionamide tbprofiler
# ERR4812768 ethionamide mykrobe
# ERR4828698 ethionamide mykrobe
# ERR4796527 ethionamide mykrobe
# ERR4796978 ethionamide tbprofiler
# ERR4812971 ethionamide mykrobe
# ERR3287345 ethionamide tbprofiler
# ERR4809059 ethionamide mykrobe
# ERR4831209 ethionamide tbprofiler
# ERR4797305 ethionamide mykrobe
# ERR3287830 ethionamide mykrobe
# ERR4822303 ethionamide tbprofiler
# ERR4796745 ethionamide tbprofiler
# ERR4800009 ethionamide mykrobe
# ERR4830797 ethionamide tbprofiler
# SRR6824414 ethionamide mykrobe
# ERR4812978 ethionamide tbprofiler
# ERR4798141 ethionamide tbprofiler
# ERR4831372 ethionamide mykrobe
# ERR4830798 ethionamide tbprofiler
# ERR4796380 ethionamide mykrobe
# SRR6824373 ethionamide mykrobe
# ERR2510255 ethionamide mykrobe

# %%
pheno
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 pheno
#
# NameError: name 'pheno' is not defined

# %%
inh_fp.intersection(eto_fp)
# Out:
# {'SRR12395058', 'SRR12395148', 'SRR12395329'}

# %% [markdown]
# RIF
# ---
# SRR14196840 FN mykrobe calls rpoB_L452P-CTG761160CCG (5/85) drprg didn't discover the variant (rpoB 1454). There is a variant at 1449 that has a null genotype and only has depth on the reverse ref allele, so maybe this meant de novo didn't get triggered...
# ERR9030523 FN mykrobe calls rpoB_D435V-GAC761109GTC (1/29) drprg didn't discover the variant (rpoB 1403)
#
# STM
# ---
# SRR12395106 FN mykrobe calls some HET looking long indels (~pos. 329 in gid) drprg calls a novel variant gid_V110V, a8V and D67Y (all called by tbprofiler)
# SRR12395154 FN mykrobe calls rpsL_K43R-AAG781686AGG (8/13) drprg called the allele, but failed FRS (0.52)
#
# ETO
# ---
#
#
#
# PZA
# ---
# SRR12395331 FN mykrobe calls pncA_R154G-CCT2288780CCC (0/13) drprg calls the correct allele, but fails FRS (0.54)

# %%
df.query()
